# %%
import pandas as pd
df=pd.read_csv('vilexnorm_clean_candidates.csv')
df=df.sample(n=1000, random_state=42)
df.to_csv('data\\external\\vilexnorm\\curated\\vilexnorm_clean_p2p_label0.csv', index=False)
