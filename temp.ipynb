# %%
import pandas as  pd
import numpy as np

df = pd.read_csv("hard_negative_label_1.csv")
df = df.drop_duplicates(subset=["category"], keep="first")
counts = df["category"].value_counts()
print(counts)
# Out:
# category
# Lừa đảo mượn tiền       104
# Lừa đảo link độc hại     66
# Lừa đảo nhầm số          60
# Lừa đảo việc làm         43
# Lừa đảo đầu tư           26
# Lừa đảo nhờ vả           24
# Lừa đảo tình cảm         22
# Lừa đảo nhận quà         16
# Lừa đảo trúng thưởng     15
# Name: count, dtype: int64

# %%
df.to_csv("hard_negative_label_1.csv", index=False)
